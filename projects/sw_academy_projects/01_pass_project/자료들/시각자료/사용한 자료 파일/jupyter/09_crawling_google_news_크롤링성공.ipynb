# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import datetime

# %%
# 뉴스 제목들을 모아 둘 리스트 생성
news = []

# 날짜 설정 start_date
sd = datetime.datetime(2021, 7, 1)

# 날짜 설정 end_date
ed = datetime.datetime(2022, 12, 31)

# +-날짜 계산해줄 nd 설정
nd = datetime.timedelta(days=1)

# 검색어 정의
search = 'netflix'

# 요청자 정보
header = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}

# while문 시작 #########################################################################################################################################################################
# while 문으로 기간 안에 있는 뉴스기사 가져오기
while sd != ed:
    
    # google 날짜 형식에 맞게 변경
    dd = sd.strftime('%m/%d/%Y')

    # url 정의
    url = f'https://www.google.com/search?q={search}&tbs=cdr:1,cd_min:{dd},cd_max:{dd}&tbm=nws'

    # 요청
    res = requests.get(url, headers=header)

    # html 읽어오고, bs4로 정돈
    html = BeautifulSoup(res.text, 'lxml')

    # 뉴스기사들 태그, 클래스 가져오기
    articles = html.find_all('div', 'mCBkyc ynAwRc MBeuO nDgy9d')

    # 뉴스기사가 없다면 pass
    if articles:

        # 뉴스기사 텍스트 추출해서 news리스트에 담기
        for article in articles:

            # 데이터프레임에 넣을 날짜형식 정의
            ad = sd.strftime('%Y-%m-%d')

            # news리스트에 날짜와 기사제목 넣기
            news.append([ad, article.text.replace('\n', '')])

    else:
        pass
    
    print(f'{dd}완료', end='  ')
    # sd + 1씩
    sd += nd

# while문 끝 ###########################################################################################################################################################################
print('크롤링 완료')
# Out:
# 07/01/2021완료  07/02/2021완료  07/03/2021완료  07/04/2021완료  07/05/2021완료  07/06/2021완료  07/07/2021완료  07/08/2021완료  07/09/2021완료  07/10/2021완료  07/11/2021완료  07/12/2021완료  07/13/2021완료  07/14/2021완료  07/15/2021완료  07/16/2021완료  07/17/2021완료  07/18/2021완료  07/19/2021완료  07/20/2021완료  07/21/2021완료  07/22/2021완료  07/23/2021완료  07/24/2021완료  07/25/2021완료  07/26/2021완료  07/27/2021완료  07/28/2021완료  07/29/2021완료  07/30/2021완료  07/31/2021완료  08/01/2021완료  08/02/2021완료  08/03/2021완료  08/04/2021완료  08/05/2021완료  08/06/2021완료  08/07/2021완료  08/08/2021완료  08/09/2021완료  08/10/2021완료  08/11/2021완료  08/12/2021완료  08/13/2021완료  08/14/2021완료  08/15/2021완료  08/16/2021완료  08/17/2021완료  08/18/2021완료  08/19/2021완료  08/20/2021완료  08/21/2021완료  08/22/2021완료  08/23/2021완료  08/24/2021완료  08/25/2021완료  08/26/2021완료  08/27/2021완료  08/28/2021완료  08/29/2021완료  08/30/2021완료  08/31/2021완료  09/01/2021완료  09/02/2021완료  09/03/2021완료  09/04/2021완료  09/05/2021완료  09/06/2021완료  09/07/2021완료  09/08/2021완료  09/09/2021완료  09/10/2021완료  09/11/2021완료  09/12/2021완료  09/13/2021완료  09/14/2021완료  09/15/2021완료  09/16/2021완료  09/17/2021완료  09/18/2021완료  09/19/2021완료  09/20/2021완료  09/21/2021완료  09/22/2021완료  09/23/2021완료  09/24/2021완료  09/25/2021완료  09/26/2021완료  09/27/2021완료  09/28/2021완료  09/29/2021완료  09/30/2021완료  10/01/2021완료  10/02/2021완료  10/03/2021완료  10/04/2021완료  10/05/2021완료  10/06/2021완료  10/07/2021완료  10/08/2021완료  10/09/2021완료  10/10/2021완료  10/11/2021완료  10/12/2021완료  10/13/2021완료  10/14/2021완료  10/15/2021완료  10/16/2021완료